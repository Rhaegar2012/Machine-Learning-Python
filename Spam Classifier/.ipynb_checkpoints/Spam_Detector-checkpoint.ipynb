# %%
#Data preparation
import os
import email as em
ham_Source_1=r"C:\Users\joseb\Documents\GitHub\Machine-Learning-Python\Spam Classifier\easy_ham\easy_ham"
spam_Source_1=r"C:\Users\joseb\Documents\GitHub\Machine-Learning-Python\Spam Classifier\spam_2\spam_2"
def get_first_text_part(msg):
    maintype = msg.get_content_maintype()
    if maintype == 'multipart':
        for part in msg.get_payload():
            if part.get_content_maintype() == 'text':
                return part.get_payload()
    elif maintype == 'text':
        return msg.get_payload()
def string_transformation(email_path):
    """
    Input: Email file (as txt) file path
    Output: nested list of words per email
    Extracts words from an email file filtering all the characters such as digits
    punctuation and space
    """
    os.chdir(email_path)
    file_list=os.listdir(email_path)
    emails=[]
    processed_emails=[]
    for file in file_list:
        try:
            email_file=open(file)
        except UnicodeDecodeError:
            email_file=open(file,"rb")
        email_text=email_file.read()
        email_object=em.message_from_string(email_text)
        email=get_first_text_part(email_object)
        emails.append(email)
    for e in range(len(emails)-1):
        if emails[e] is not None:
            first_stage=emails[e].lower()
            second_stage=first_stage.strip()
            third_stage=second_stage.split()
            for word in third_stage:
                word=''.join(char for char in word if char.isalpha())
            filters=0
            while filters<10:
                for word in third_stage:
                    word_index=third_stage.index(word)
                    for char in word:
                        if char in "1234567890.!@?$_-()[]{},+│/*=:;<>\"":
                            new_word=word.replace(char,"")
                            third_stage[word_index]=new_word
            
                filters+=1
        processed_emails.append(third_stage)
    return processed_emails

ham_emails=string_transformation(ham_Source_1)
spam_emails=string_transformation(spam_Source_1)
blocks=[ham_emails,spam_emails]

# %%
len(ham_emails[0])
# Out:
# 225

# %%
ham_emails[0]
if "jose" not in ham_emails[0]:
    print("No estoy")
else:
    print("estoy")
# Out:
# No estoy

# %%
def generate_bag_of_words(email_block,bag_of_words):
    for email in email_block:
        for word in email:
            if word not in bag_of_words:
                bag_of_words.append(word)
    return bag_of_words
            
def vectorize(email_block,bag_of_words):
    vector_block=[]
    vector=[]
    for email in email_block:
        for word in email:
            if word not in bag_of_words:
                vector.append(0)
            else:
                vector.append(1)
        vector_block.append(vector)
        vector=[]
    return vector_block

initial_bag=[]
for block in blocks:
    block_bag=generate_bag_of_words(block,initial_bag)
    initial_bag=block_bag
block_bag
# Out:
# ['date',
#  'wed',
#  '',
#  'aug',
#  'from',
#  'chris',
#  'garrigues',
#  '<cwg-dated-faddeepeddycom',
#  'messageid',
#  '<1tmdadeepeddyvirciocom',
#  '|',
#  'i',
#  "can't",
#  'reproduce',
#  'this',
#  'error',
#  'for',
#  'me',
#  'it',
#  'is',
#  'very',
#  'repeatable',
#  'like',
#  'every',
#  'time',
#  'without',
#  'fail',
#  'the',
#  'debug',
#  'log',
#  'of',
#  'pick',
#  'happening',
#  'pickit',
#  'exec',
#  'inbox',
#  'list',
#  'lbrace',
#  'subject',
#  'ftp',
#  'rbrace',
#  'sequence',
#  'mercury',
#  'ftocpickmsgs',
#  'hit',
#  'marking',
#  'hits',
#  'tkerror',
#  'syntax',
#  'in',
#  'expression',
#  'int',
#  'note',
#  'if',
#  'run',
#  'command',
#  'by',
#  'hand',
#  'delta',
#  "that's",
#  'where',
#  'comes',
#  'obviously',
#  'version',
#  'nmh',
#  "i'm",
#  'using',
#  'compiled',
#  'on',
#  'fuchsiacsmuozau',
#  'at',
#  'sun',
#  'mar',
#  'ict',
#  'and',
#  'relevant',
#  'part',
#  'my',
#  'mhprofile',
#  'mhparam',
#  'seq',
#  'sel',
#  'since',
#  'works',
#  'actually',
#  'both',
#  'them',
#  'one',
#  'explicit',
#  'line',
#  'search',
#  'popup',
#  'that',
#  'do',
#  'get',
#  'created',
#  'kre',
#  'ps',
#  'still',
#  'code',
#  'form',
#  'a',
#  'day',
#  'ago',
#  "haven't",
#  'been',
#  'able',
#  'to',
#  'reach',
#  'cvs',
#  'repository',
#  'today',
#  'local',
#  'routing',
#  'issue',
#  'think',
#  'exmhworkers',
#  'mailing',
#  'exmhworkersredhatcom',
#  'httpslistmanredhatcommailmanlistinfoexmhworkers',
#  'martin',
#  'posted',
#  'tassos',
#  'papadopoulos',
#  'greek',
#  'sculptor',
#  'behind',
#  'plan',
#  'judged',
#  'limestone',
#  'mount',
#  'kerdylio',
#  'miles',
#  'east',
#  'salonika',
#  'not',
#  'far',
#  'athos',
#  'monastic',
#  'community',
#  'was',
#  'ideal',
#  'patriotic',
#  'sculpture',
#  'as',
#  'well',
#  "alexander's",
#  'granite',
#  'features',
#  'ft',
#  'high',
#  'wide',
#  'museum',
#  'restored',
#  'amphitheatre',
#  'car',
#  'park',
#  'admiring',
#  'crowds',
#  'are',
#  'planned',
#  'so',
#  'mountain',
#  'or',
#  "it's",
#  "it'll",
#  'weather',
#  'pretty',
#  'fast',
#  'yahoo',
#  'groups',
#  'sponsor',
#  '~',
#  'dvds',
#  'free',
#  's&p',
#  'join',
#  'now',
#  'httpusclickyahoocomptybbnxieaamghaagsolbtm',
#  'unsubscribe',
#  'group',
#  'send',
#  'an',
#  'email',
#  'forteanaunsubscribeegroupscom',
#  'your',
#  'use',
#  'httpdocsyahoocominfoterms',
#  'man',
#  'threatens',
#  'explosion',
#  'moscow',
#  'thursday',
#  'august',
#  'pm',
#  'ap',
#  'security',
#  'officers',
#  'seized',
#  'unidentified',
#  'who',
#  'said',
#  'he',
#  'armed',
#  'with',
#  'explosives',
#  'threatened',
#  'blow',
#  'up',
#  'his',
#  'truck',
#  'front',
#  "russia's",
#  'federal',
#  'services',
#  'headquarters',
#  'ntv',
#  'television',
#  'reported',
#  'automatic',
#  'rifle',
#  'carrying',
#  'then',
#  'got',
#  'out',
#  'taken',
#  'into',
#  'custody',
#  'no',
#  'other',
#  'details',
#  'were',
#  'immediately',
#  'available',
#  'had',
#  'demanded',
#  'talks',
#  'government',
#  'officials',
#  'interfax',
#  'itartass',
#  'news',
#  'agencies',
#  'ekho',
#  'moskvy',
#  'radio',
#  'wanted',
#  'talk',
#  'russian',
#  'president',
#  'vladimir',
#  'putin',
#  'police',
#  'forces',
#  'rushed',
#  'service',
#  'building',
#  'within',
#  'blocks',
#  'kremlin',
#  'red',
#  'square',
#  'bolshoi',
#  'ballet',
#  'surrounded',
#  'claimed',
#  'have',
#  'half',
#  'tons',
#  'negotiations',
#  'continued',
#  'about',
#  'hours',
#  'outside',
#  'citing',
#  'witnesses',
#  'later',
#  'drove',
#  'away',
#  'under',
#  'escort',
#  'street',
#  'near',
#  "moscow's",
#  'olympic',
#  'penta',
#  'hotel',
#  'authorities',
#  'held',
#  'further',
#  'him',
#  'press',
#  'move',
#  'appeared',
#  'be',
#  'attempt',
#  'more',
#  'secure',
#  'location',
#  'klez',
#  'virus',
#  "won't",
#  'die',
#  'already',
#  'most',
#  'prolific',
#  'ever',
#  'continues',
#  'wreak',
#  'havoc',
#  'andrew',
#  'brandt',
#  'september',
#  'pc',
#  'world',
#  'magazine',
#  'worm',
#  'approaching',
#  'its',
#  'seventh',
#  'month',
#  'wriggling',
#  'across',
#  'web',
#  'making',
#  'persistent',
#  'viruses',
#  'experts',
#  'warn',
#  'may',
#  'harbinger',
#  'new',
#  'combination',
#  'pernicious',
#  'approaches',
#  'go',
#  'antivirus',
#  'software',
#  'makers',
#  'symantec',
#  'mcafee',
#  'report',
#  'than',
#  'infections',
#  'daily',
#  'sign',
#  'letup',
#  'british',
#  'firm',
#  'messagelabs',
#  'estimates',
#  'messages',
#  'holds',
#  'variation',
#  'says',
#  'has',
#  'surpassed',
#  'last',
#  "summer's",
#  'sircam',
#  'some',
#  'newer',
#  'variants',
#  "aren't",
#  'merely',
#  'nuisancesthey',
#  'can',
#  'carry',
#  'corrupt',
#  'data',
#  'httpwwwpcworldcomnewsarticleaidasp',
#  'irregulars',
#  'irregularstbtf',
#  'httptbtfmailmanlistinfoirregulars',
#  'ulises',
#  'ponce',
#  'wrote',
#  'hi',
#  'there',
#  'insert',
#  'signature',
#  'keys',
#  'sent',
#  'mail',
#  'simply',
#  'put',
#  'component',
#  'files',
#  'components',
#  'replcomps',
#  'forwcomps',
#  'way',
#  'you',
#  'when',
#  'editing',
#  'message',
#  'also',
#  'comps',
#  'specific',
#  'folders',
#  'alter',
#  'sig',
#  'per',
#  'folder',
#  'tricks',
#  'see',
#  'docs',
#  'all',
#  'might',
#  'must',
#  'sedit',
#  'but',
#  "i've",
#  'gvim',
#  'exmh',
#  'editor',
#  'long',
#  'load',
#  'loads',
#  'emailspecific',
#  'settings',
#  'eg',
#  'colourhighlight',
#  'headers',
#  'quoted',
#  'parts',
#  'would',
#  'possible',
#  'map',
#  'vim',
#  'add',
#  'even',
#  'give',
#  'selection',
#  'sigs',
#  'choose',
#  'sorts',
#  'ways',
#  'randomlychosen',
#  'somewhere',
#  'rtfmmitedu',
#  'ok',
#  'here',
#  'we',
#  'rtfmmitedupubusenetbygroupnewsanswerssignaturefingerfaq',
#  'warning',
#  'old',
#  'regards',
#  'hope',
#  'helps',
#  'cheers',
#  'tony',
#  'exmhusers',
#  'exmhusersredhatcom',
#  'httpslistmanredhatcommailmanlistinfoexmhusers',
#  'adding',
#  'cream',
#  'spaghetti',
#  'carbonara',
#  'which',
#  'same',
#  'effect',
#  'pasta',
#  'pizza',
#  'deeppie',
#  'just',
#  'jump',
#  'favourites',
#  'make',
#  'ask',
#  'what',
#  'hell',
#  'supposed',
#  'instead',
#  'never',
#  'seen',
#  'recipe',
#  "hasn't",
#  'used',
#  'personally',
#  'low',
#  'fat',
#  'creme',
#  'fraiche',
#  'because',
#  'quite',
#  'nicely',
#  'only',
#  'supposedly',
#  'authentic',
#  'identical',
#  'mine',
#  'eggs',
#  'lots',
#  'fresh',
#  'parmesan',
#  'except',
#  'stew',
#  'stewart',
#  'smith',
#  'scottish',
#  'microelectronics',
#  'centre',
#  'university',
#  'edinburgh',
#  'httpwwweeedacuk~sxs',
#  "isn't",
#  'basically',
#  'mixture',
#  'beaten',
#  'egg',
#  'bacon',
#  'pancetta',
#  'really',
#  'mix',
#  'raw',
#  'cooked',
#  'heat',
#  'cooks',
#  'understanding',
#  'scotsman',
#  'playboy',
#  'wants',
#  'bang',
#  'ageing',
#  'berlin',
#  'come',
#  'unusual',
#  'offer',
#  'lure',
#  'women',
#  'bed',
#  'promising',
#  'woman',
#  'sleeps',
#  'inheritance',
#  '£',
#  'rolf',
#  'eden',
#  'disco',
#  'owner',
#  'famous',
#  'countless',
#  'sex',
#  'partners',
#  'could',
#  'imagine',
#  'better',
#  'arms',
#  'attractive',
#  'young',
#  'preferably',
#  'will',
#  'testament',
#  'gets',
#  'money',
#  'mr',
#  'told',
#  'bild',
#  'newspaper',
#  'want',
#  'pass',
#  'beautiful',
#  'moment',
#  'life',
#  'first',
#  'lot',
#  'fun',
#  'wild',
#  'final',
#  'orgasm',
#  'end',
#  'heart',
#  'attack',
#  'i’m',
#  'gone',
#  'selling',
#  'nightclub',
#  'year',
#  'applications',
#  'should',
#  'quickly',
#  'age',
#  'soon',
#  'adamson',
#  "you're",
#  'probably',
#  'right',
#  "mine's",
#  'added',
#  'guess',
#  'try',
#  'looking',
#  'internet',
#  'found',
#  'possibly',
#  'scariest',
#  'people',
#  "he's",
#  'us',
#  'congressman',
#  'httpwwwvirtualcitiescomonsmegovmegvjbhtm',
#  'worst',
#  'nonsmiles',
#  'apologies',
#  'any',
#  "list's",
#  'maine',
#  'residents',
#  'voted',
#  'again',
#  'once',
#  "you've",
#  'pic',
#  'thu',
#  'meaningful',
#  'sentences',
#  'tracey',
#  'lawson',
#  'look',
#  'dangerous',
#  'inmates',
#  'prison',
#  'history',
#  'judge',
#  'described',
#  'charles',
#  'bronson',
#  'now’s',
#  'chance',
#  'serial',
#  'hostage',
#  'taker',
#  'movie',
#  'star',
#  'written',
#  'health',
#  'fitness',
#  'guide',
#  'shares',
#  'secrets',
#  'legendary',
#  'muscle',
#  'power',
#  'solitary',
#  'title',
#  'bears',
#  'fact',
#  'spent',
#  'years',
#  'confinement',
#  'explains',
#  'how',
#  'turned',
#  'himself',
#  'lean',
#  'mean',
#  'machine',
#  'while',
#  'living',
#  'space',
#  'feet',
#  'eight',
#  'diet',
#  'scrubs',
#  'grub',
#  'virtually',
#  'cost',
#  'book',
#  'aimed',
#  'those',
#  'fabulously',
#  'fit',
#  'spending',
#  'fortune',
#  'gym',
#  'memberships',
#  'protein',
#  'supplements',
#  'designer',
#  'trainers',
#  'starts',
#  'fierce',
#  'expensive',
#  'myths',
#  'churned',
#  'exercise',
#  'industry',
#  'mag',
#  'start',
#  'laugh',
#  'wipe',
#  'arse',
#  'opening',
#  'paragraph',
#  'penned',
#  'it’s',
#  'joke',
#  'big',
#  'con',
#  'they',
#  'call',
#  'criminal',
#  'can’t',
#  'help',
#  'feeling',
#  'point',
#  'bars',
#  'having',
#  'published',
#  'birdman',
#  'opens',
#  'mind',
#  'drawings',
#  'poems',
#  'prisoner',
#  'discover',
#  'creative',
#  'residing',
#  'her',
#  'majesty’s',
#  'pleasure',
#  'jimmy',
#  'boyle',
#  'scots',
#  'novelist',
#  'discovered',
#  'artistic',
#  'talents',
#  'barlinnie',
#  'prison’s',
#  'special',
#  'unit',
#  'their',
#  'violent',
#  'pasts',
#  'teaching',
#  'express',
#  'emotions',
#  'artistically',
#  'sentenced',
#  'murder',
#  'babs',
#  'rooney',
#  'released',
#  'moved',
#  'become',
#  'respected',
#  'artist',
#  'novel',
#  'hero',
#  'underworld',
#  'autobiography',
#  'sense',
#  'freedom',
#  'made',
#  'awardwinning',
#  'film',
#  'hugh',
#  'collins',
#  'jailed',
#  'william',
#  'mooney',
#  'glasgow',
#  'stabbed',
#  'three',
#  'earning',
#  'extra',
#  'sevenyear',
#  'sentence',
#  'after',
#  'being',
#  'transferred',
#  'attended',
#  'learned',
#  'sculpt',
#  'developed',
#  'interest',
#  'art',
#  'murderer',
#  'frank',
#  'account',
#  'glasgow’s',
#  'culture',
#  's',
#  'received',
#  'critical',
#  'praise',
#  'lord',
#  'archer',
#  'doesn’t',
#  'seem',
#  'trouble',
#  'continuing',
#  'write',
#  'books',
#  'millions',
#  'jail',
#  'recently',
#  'signed',
#  'threebook',
#  'deal',
#  'macmillan',
#  'publishers',
#  'worth',
#  'million',
#  'doubt',
#  'scribbling',
#  'speak',
#  'why',
#  'men',
#  'destructive',
#  'towards',
#  'society',
#  'stuck',
#  'inside',
#  'steve',
#  'richards',
#  'bronson’s',
#  'publisher',
#  'many',
#  'figures',
#  'believes',
#  'roots',
#  'phenomenon',
#  'pragmatic',
#  'profound',
#  'sometimes',
#  'criminals',
#  'known',
#  'stable',
#  'environment',
#  'focus',
#  'skills',
#  'education',
#  'early',
#  'hard',
#  'anyone',
#  'offered',
#  'explore',
#  'however',
#  'reasons',
#  'deeper',
#  'cold',
#  'light',
#  'examine',
#  'essence',
#  'themselves',
#  'am',
#  'remembered',
#  'violence',
#  'contribute',
#  'something',
#  'good',
#  'born',
#  'michael',
#  'gordon',
#  'peterson',
#  'changed',
#  'name',
#  'hollywood',
#  'death',
#  'wish',
#  'films',
#  'mainly',
#  'things',
#  'bad',
#  'originally',
#  'seven',
#  'robbery',
#  'series',
#  'original',
#  'term',
#  'over',
#  'result',
#  'attacking',
#  'convicted',
#  'holding',
#  'teacher',
#  'nearly',
#  'two',
#  'days',
#  'during',
#  'siege',
#  'standing',
#  'five',
#  'ten',
#  'inches',
#  'tall',
#  'weighing',
#  'lbs',
#  'renowned',
#  'strength',
#  'bent',
#  'metal',
#  'cell',
#  'doors',
#  'bare',
#  'hands',
#  'does',
#  'yes',
#  'pressups',
#  'puts',
#  'times',
#  'four',
#  'seconds',
#  'push',
#  'ups',
#  'judging',
#  'our',
#  'current',
#  'obsession',
#  'face',
#  'sitting',
#  'coffee',
#  'table',
#  'land',
#  'dream',
#  'body',
#  'socalled',
#  'gurus',
#  'promise',
#  'motivate',
#  'words',
#  'powerfully',
#  'fists',
#  'crap',
#  'highprotein',
#  'drinks',
#  'pills',
#  'diets',
#  'bollocks',
#  'multimillionpound',
#  'racket',
#  'writes',
#  'refreshingly',
#  'honest',
#  'style',
#  'lazy',
#  'bastards',
#  'choice',
#  'sick',
#  'hearing',
#  'reading',
#  'excuses',
#  'stuff',
#  'shit',
#  'that’s',
#  'logical',
#  'motivational',
#  'mantras',
#  'kick',
#  'er',
#  'backside',
#  'needed',
#  'mirage',
#  'publishing',
#  'bookstores',
#  'october',
#  'j',
#  'w',
#  'ballantine',
#  'jwbhomerattcom',
#  "cvs'ed",
#  'unseensequences',
#  'changes',
#  'installed',
#  'real',
#  'unseen',
#  'window',
#  'rather',
#  'icon',
#  'main',
#  'open',
#  'necessary',
#  'hmmm',
#  'stole',
#  'unseenwin',
#  'tested',
#  "don't",
#  'functionality',
#  'consider',
#  'check',
#  'httpwwwdeepeddycom~cwg',
#  'vircio',
#  'httpwwwvirciocom',
#  'congress',
#  'suite',
#  'austin',
#  'tx',
#  'war',
#  'iii',
#  'wrongdoers',
#  'vs',
#  'evildoers',
#  'trying',
#  'research',
#  'via',
#  'sa',
#  'mirrors',
#  ...]

# %%
len(block_bag)
# Out:
# 63875

# %%
random.shuffle(block_bag)
print(block_bag)
# Out:
# ['alled', 'httpreuterscomnewsarticlejhtmltypeentertainmentnews&storyid', 'citratebr', 'pcipjxipjxbighyzwyimhawxbzpbnnynnjcjexmkblegnpdguuyt', 'neared', 'pjxipjxhighyzwyimhawxbzpzdgfybhlaynrhbwfpbcuzxquyipkns', 'fishermen', 'initiated', 'decssexe', 'colorpurple', 'lire', 'recreational', 'omnioutliner', 'zqqffvsuulttxfunction', "earnhardt's", 'trollbox', 'orm', 'httpmemriorgbinarticlescgipagearchives&areaia&idia', 'mailtobgtyuuolcomcosubjectexcludefams', 'refocus', 'titlefor', 'aio', 'lifeb', 'downsizing', 'mailtomoderatoraeopublishingcomto', 'dhvbgvzywxlcbvcnrzlbhzuuahrtbdtbrlpwlzwwywdljmzpbgu', 'chapman', 'beans', 'destructor', 'snot', 'motherboards', 'sample', 'dramaticallyemphatically', 'physician', 'zumzmlsztvcgfnzspdgvtcgfnzxyllzwwywdllnnwbczwcmksuq', 'roannaelitistsco', 'httpwwwbbccoukradioaltnirelandniteamshtml', 'point”', 'starttls', 'disablelibdv', 'ddlmjcluzxnzbwfpbgxpcquytlzwvcbhbjledqobzpwpjwvbzpwpjwvcbh', 'brin', 'satislarinizi', "'how", 'linksys', 'rdo', 'facearialoptinfontli', 'ddaccbfaaacddbcbbdceacfacabbcc', 'noah', 'cybercare', 'outperforming', 'ganav', 'plouisville', 'ytlnnasiawvcgfnzwdlbicrvcmvzcgydhmvymvsbdagszxnh', 'cfule', "href'httpwwwhipaaiqcom'public", 'shivering', 'namedaddressfont', 'bignvbgypsijmznmzjmzijncialzvbnqphupgzvbnqgysbi', 'individualfontbtd', 'conforms', 'srchttpwwwforeclosureschoolcomimagesforeclosuresuncoveredtextgif', 'configmak', 'papaver', 'gbupdateprobabilities', 'appointments', 'caching', 'mvuyrbjoefexbxbqnxqafujbgnn', 'reliability', 'classical', 'bgcolordcc', 'ulbfont', 'piagphrypiadgqpgnlbnrlcjzmudcbzaxplptegzmfjztiyxjpywwi', 'nbsp&nbsp', 'soto', 'incríveis', 'bodyfat', 'exmhdebug', 'netcelebs', "hundt's", 'sizedstarting', 'webpages', '%%d%yth%%num%b%red%%d%kiw%%bon%%teg%b%wes%', 'nospam', "'trtr'", 'textd', 'mmc', 'hrefhttp:6.23.22.ldabgaid', 'oscillate', 'angry', 'ottomans', 'dghligludgvybmvlcbagugnqkcmvwbjcybbugchvyyhhcugdls', 'powerpc', 'routinely', 'grantsfontfontul', 'sizehumjman', 'registercom', 'valuedafternoon', 'liintegrated', 'names', 'capacitive', 'compute', 'i', 'investement', 'regularfont', 'smrazor', 'enterprisescalable', 'pipe…as', 'bluebe', 'fireworks', 'fist', 'plataforma', 'gxxpersonalityv', 'lz', '5javamailrovadminrovweb', 'namedsubmitted', 'sizedbcfacf', 'exceedingly', 'based', 'seismic', 'lcbztuncknbtibsruxbwcwgymvjyxvzzsbagugclzdgvtiglzigfscmvh', 'domesticviolence', 'spears', 'demipublican', 'compmailmime', '(httpwwwlinksyscomproductsproductaspgrid&prid', 'bushies', 'httpwwwwallacoil', 'amber', 'backticks', 'accelerate', "'deliveredtoskips", 'supress', 'vowed', 'arrrg', 'pointofsale', 'llength', 'colorredfree', 'rebuttal', 'environments', 'timet', 'specification', 'stylefontsizeptmsobidifontsizeptfontfamilyarialthe', 'napaba', 'rows', 'bdo', 'arrange', 'fast', 'httpwwwsellinternetaccesscom', 'usernamenobody', '8user00indexaspafftdqmimg', 'coordsize', 'auctionbr', 'herpesbr', 'sd', 'otcvtgestrongbigfonttd', 'webdings', 'callthis', 'laws', 'usrincludesystypesh', 'urlhttpwwwsancristobalsanetletterimagesbggif', 'hall', 'mdawpjxmbigzhyuvgfobhpgksgksigpticgpgjypjxicjnclf', 'namedlastname', 'chancellor', 'gh', "styled'textaligncenter'&nbspp", 'styledbackgroundcolora', 'cutbuffer', 'culd', 'mam', 'worldcomlike', 'protégé', 'tofontdiv', 'paradigmomega', 'sweated', 'selectedcbabdaba', 'noon', 'icagicanciagicagicagicagicagicagicagpfrspgkicagicagicagicag', 'ightdfont', 'sword', 'dropout', 'uncertainties', 'smb', 'sol', 'liquidators', "kaho'olawe", 'httpinsightmagcomnewshtm', 'originality&nbsp', 'self', 'styledbac', 'bufont', 'hrefhttpwwwlinksprofitcomhttpwwwlinksprofitcomaby', 'glowing', 'breakthroughpour', 'httpwwwwiildaccesscomoptouthtml', 'provincefonttd', 'sds', 'peaceable', 'id&usernum', 'sizevoteon', 'limsthemenavtxtnext', 'diveintomarkorg', 'he’s', 'phonebr', 'propagation', 'forecast', '[bfryte^324(^(pokjjbjk^h', 'wilberforce', 'vielhemfont', 'squirters', 'srchttpwwwpornstarsxtracombabesbrianaimagesthumbjpga', 'hrefhttpwwwaffiliatesukcomhttpwwwaffiliatesukcoma',  ...

# %%
ham_vector=vectorize(ham_emails,block_bag)
spam_vector=vectorize(spam_emails,block_bag)

# %%
# Out:
# there is a least a 1
# 120
